# %%
import pandas as pd

#G2: Primarikey as country id
df_WB_g2_riskpremium = pd.read_csv('WorldBank-riskpremium/API_FR.INR.RISK.csv', skiprows=4)
df_WB_g2_persremi =  pd.read_csv('WorldBank-personalremittances/API_BX.TRF.PWKR.CD.DT_DS2.csv',skiprows=4)
df_WB_g2_lendingir =  pd.read_csv('WorldBank-lendingir/API_FR.INR.LEND_DS2.csv',skiprows=4)
df_WB_g2_depositors =  pd.read_csv('WorldBank-depositors/API_FB.CBK.BRWR.P3_DS2.csv',skiprows=4)

# %%
df_WB_g2_riskpremium.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name Indicator Code  1960  \
# 0  Risk premium on lending (lending rate minus tr...    FR.INR.RISK   NaN
# 1  Risk premium on lending (lending rate minus tr...    FR.INR.RISK   NaN
# 2  Risk premium on lending (lending rate minus tr...    FR.INR.RISK   NaN
# 3  Risk premium on lending (lending rate minus tr...    FR.INR.RISK   NaN
# 4  Risk premium on lending (lending rate minus tr...    FR.INR.RISK   NaN
#
#    1961  1962  1963  1964  1965  ...      2013       2014      2015      2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...       NaN        NaN       NaN       NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...       NaN        NaN       NaN       NaN
# ...

# %%
#G1: INDICATOR_CODE	Explanation for G2
df_WB_g1_riskpremium = pd.read_csv('WorldBank-riskpremium/Metadata_Indicator_API_FR.INR.RISK.csv')
df_WB_g1_persremi =  pd.read_csv('WorldBank-personalremittances/Metadata_Indicator_API_BX.TRF.PWKR.CD.DT_DS2.csv')
df_WB_g1_lendingir =  pd.read_csv('WorldBank-lendingir/Metadata_Indicator_API_FR.INR.LEND_DS2.csv')
df_WB_g1_depositors =  pd.read_csv('WorldBank-depositors/Metadata_Indicator_API_FB.CBK.BRWR.P3_DS2.csv')
df_WB_g1_indicators = pd.concat([df_WB_g1_riskpremium, df_WB_g1_persremi,df_WB_g1_lendingir,df_WB_g1_depositors], ignore_index=True)

df_WB_g1_indicators.head()
# Out:
#       INDICATOR_CODE                                     INDICATOR_NAME  \
# 0        FR.INR.RISK  Risk premium on lending (lending rate minus tr...
# 1  BX.TRF.PWKR.CD.DT       Personal remittances, received (current US$)
# 2        FR.INR.LEND                          Lending interest rate (%)
# 3     FB.CBK.BRWR.P3  Borrowers from commercial banks (per 1,000 adu...
#
#                                          SOURCE_NOTE  \
# 0  Risk premium on lending is the interest rate c...
# 1  Personal remittances comprise personal transfe...
# 2  Lending rate is the bank rate that usually mee...
# 3  Borrowers from commercial banks are the report...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  International Monetary Fund, International Fin...         NaN
# 1  World Bank staff estimates based on IMF balanc...         NaN
# 2  International Monetary Fund, International Fin...         NaN
# 3  International Monetary Fund, Financial Access ...         NaN

# %%
#G2: Primarikey as country id
conda install openpyxl
df_VPB_g2_cardassociate = pd.read_excel('VPB_CardAssociate/Card market share 2019.xlsx')                 
df_VPB_g2_cardassociate.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\compat\_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     140 try:
# --> 141     module = importlib.import_module(name)
#     142 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...
